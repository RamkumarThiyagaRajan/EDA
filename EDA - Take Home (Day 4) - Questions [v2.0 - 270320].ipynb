# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Take-Home <br>(Day 4)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Life Expectancy Data)
#
# The dataset contains the health data of 2938 individuals useful for predicting the life expentency of the individuals. The features are related to economical factors, immunity realted factors, social factors and so on.
#
# Attribute Information:
#
# **Country:** Country of the recorded data
#
# **Year:** Year of the recorded data
#
# **Status:** Status of the country
#
# **Life expectancy:** Life expectancy in age (target/dependent variable)
#
# **Adult mortality:** Rate of adult mortality
#
# **Infant deaths:** Number of Infant Deaths per 1000 population
#
# **Alcohol:** Alcohol consumption (in litres of pure alcohol)
#
# **Percentage expenditure:** Expenditure on health as a percentage of GDP
#
# **Hepatitis B:** Hepatitis B immunization coverage among 1-year-olds (%)
#
# **Measles:** Number of reported cases per 1000 population
#
# **BMI:** Average BMI of entire population
#
# **Under-five deaths:** Number of under-five deaths per 1000 population
#
# **Polio:** Polio immunization coverage among 1-year-olds (%)
#
# **Total expenditure:** Government expenditure on health as a percentage of total government expenditure (%)
#
# **Diphtheria:** DTP3 immunization coverage among 1-year-olds (%)
#
# **HIV/AIDS:** Deaths per 1000 live births HIV/AIDS (0-4 years)
#
# **GDP:** Gross Domestic Product per capita (in USD)
#
# **Population:** Population of the country
#
# **Thinness 1-19 years:** Prevalence of thinness for age 1 to 19 (%)
#
# **Thinness 5-9 years:** Prevalence of thinness for age 5 to 9 (%)
#
# **Income composition of resources:** Human Development Index in terms of income composition of resources
#
# **Schooling:** Number of years of Schooling

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the life expectancy dataset and print the first five observations

# %%
# type your code here
data=pd.read_csv('Life Expectancy Data.csv')
data
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Check the data type of each variable and if any variable is wrongly identified, do the needful</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
data.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult mortality                    float64
# Infant deaths                        int64
# Alcohol                            float64
# Percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# Under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                          object
# Thinness  1-19 years               float64
# Thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %% [markdown]
# ##### INFERENCE:-
#     POPULATION IS wrongly identified BUT CANOT CONVERT IT BECAUSE IT CONTAINS #

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Create a DataFrame containing the count and percentage of missing entries in each variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
data.shape
# Out:
# (2938, 22)

# %%
i=data.isnull().sum().value_counts()
i
# Out:
# 0      8
# 34     3
# 19     2
# 10     2
# 448    1
# 16     1
# 226    1
# 553    1
# 167    1
# 163    1
# 194    1
# dtype: int64

# %%
c=data.isnull().sum().sum()/data.shape[0]*100
c
# Out:
# 65.58883594281825

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3a. Are there any extreme values present in the government's total expenditure on health?
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.boxplot(data['Total expenditure'])
plt.show()

# %% [markdown]
# ##### INFERENCE:-
#     YES extreme values present in the government's total expenditure on health

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3b. Remove the outliers present in 'Total expenditure' using the quartiles of the variable
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
i='Total expenditure'
q3=data[i].quantile(0.75)
q1=data[i].quantile(0.25)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr

data[(data[i]>ub) | (data[i]<lb)]['Total expenditure']
# Out:
# 1386    13.66
# 1496    14.39
# 1573    12.60
# 1603    13.73
# 1650    17.24
# 1700    13.71
# 1701    13.38
# 1702    12.77
# 1703    13.76
# 1704    13.83
# 1705    13.44
# 1706    12.94
# 2108    12.80
# 2109    12.49
# 2303    13.13
# 2312    13.63
# 2713    16.61
# 2795    17.14
# 2796    16.90
# 2797    17.20
# 2798    17.60
# 2799    17.20
# 2800    17.00
# 2801    16.20
# 2802    15.57
# 2803    15.27
# 2804    15.15
# 2805    15.14
# 2806    15.60
# 2807    14.55
# 2808    13.73
# 2809    13.70
# Name: Total expenditure, dtype: float64

# %%
data_outlier=data[(data[i]>ub) | (data[i]<lb)]
data_outlier
# Out:
#                                Country  Year      Status  Life expectancy  \
# 1386                          Kiribati  2007  Developing             65.0
# 1496                           Liberia  2009  Developing             59.2
# 1573                            Malawi  2012  Developing             55.3
# 1603                          Maldives  2014  Developing             78.2
# 1650                  Marshall Islands  2013  Developing              NaN
# 1700  Micronesia (Federated States of)  2014  Developing             69.4
# 1701  Micronesia (Federated States of)  2013  Developing             69.2
# 1702  Micronesia (Federated States of)  2012  Developing             69.0
# 1703  Micronesia (Federated States of)  2011  Developing             68.9
# 1704  Micronesia (Federated States of)  2010  Developing             68.7
# 1705  Micronesia (Federated States of)  2009  Developing             68.5
# 1706  Micronesia (Federated States of)  2008  Developing             68.4
# ...

# %%
data['Total expenditure']-data_outlier['Total expenditure']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 2933   NaN
# 2934   NaN
# 2935   NaN
# 2936   NaN
# 2937   NaN
# Name: Total expenditure, Length: 2938, dtype: float64

# %%
sns.boxplot(data_outlier['Total expenditure'])
plt.show()

# %% [markdown]
# ##### INFERENCE:-
#     TREATED ALL THE OUTLIERS

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Split the data such that 'X' will contain all the indepentdent variables and 'y' will contain the target variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Hint:** 'Life expectancy' is the target variable depending on the remaining variables.

# %%
data_new=data.fillna(data.mean())
data_new
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
from sklearn.model_selection import train_test_split
x=data_new.drop('Life expectancy',axis=1)
y=data_new['Life expectancy']
x_train_data,y_train_data,x_test_data,y_test_data=train_test_split(x,y,test_size=0.8)
print('x_train_data is',x_train_data.shape)
print('y_train_data is',y_train_data.shape)
print('x_test_data is',x_test_data.shape)
print('y_test_data is',y_test_data.shape)#the data such that 'X' will contain all the indepentdent variables and 'y' will contain the target variable
# Out:
# x_train_data is (587, 21)
# y_train_data is (2351, 21)
# x_test_data is (587,)
# y_test_data is (2351,)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Split the independent variables into two sets with the proportion of 70:30</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
from sklearn.model_selection import train_test_split
train_data,test_data=train_test_split(data,test_size=0.3)
print('train_data is',train_data.shape)
print('test_data is',test_data.shape)#the independent variables into two sets with the proportion of 70:30
# Out:
# train_data is (2056, 22)
# test_data is (882, 22)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. How would you treat the missing values in the variable 'GDP'?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data[data['GDP'].isnull()]['GDP'].isnull().sum()
# Out:
# 448

# %%
# type your code here
data[data['GDP'].isnull()]['GDP'].fillna(0)#we can treat the missing values in the variable 'GDP' with fillna=0
# Out:
# 160     0.0
# 161     0.0
# 162     0.0
# 163     0.0
# 164     0.0
#        ...
# 2901    0.0
# 2902    0.0
# 2903    0.0
# 2904    0.0
# 2905    0.0
# Name: GDP, Length: 448, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7.There are 16 observations for which the status of the corresponding country is unknown, impute this status with an appropriate values</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
data[data['Status'].isnull()]['Status']#16 observations for which the status of the corresponding country is unknown
# Out:
# 6       NaN
# 15      NaN
# 27      NaN
# 46      NaN
# 65      NaN
# 75      NaN
# 82      NaN
# 93      NaN
# 104     NaN
# 118     NaN
# 136     NaN
# 148     NaN
# 458     NaN
# 1129    NaN
# 2003    NaN
# 2068    NaN
# Name: Status, dtype: object

# %%
data[data['Status'].isnull()]['Status'].fillna(0)#impute this status with an appropriate values fillna=0
# Out:
# 6       0
# 15      0
# 27      0
# 46      0
# 65      0
# 75      0
# 82      0
# 93      0
# 104     0
# 118     0
# 136     0
# 148     0
# 458     0
# 1129    0
# 2003    0
# 2068    0
# Name: Status, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Define a function to find the extreme values in alcohol consumption
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
def extreme_values(variable):
    q3=data_new[variable].quantile(0.75)
    q1=data_new[variable].quantile(0.25)
    iqr=q3-q1
    ub=q3+1.5*iqr
    lb=q1-1.5*iqr
    return(data_new[(data_new[variable]>ub) | (data_new[variable]<lb)])
extreme_values('Alcohol')#function to find the extreme values in alcohol consumption
# Out:
#      Country  Year      Status  Life expectancy  Adult mortality  \
# 228  Belarus  2011  Developing             72.0            232.0
# 873  Estonia  2008  Developing             74.2            167.0
# 874  Estonia  2007  Developing             73.0            189.0
#
#      Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 228              0    17.31              846.911307         98.0       50
# 873              0    16.99              225.072362         94.0        0
# 874              0    17.87             1904.124690         95.0        1
#
#      ...  Polio  Total expenditure  Diphtheria  HIV/AIDS          GDP  \
# 228  ...   98.0               4.92        98.0       0.1   6519.71753
# 873  ...   95.0               6.60        95.0       0.1   1894.54850
# 874  ...   95.0               5.16        95.0       0.1  16586.45200
#
#      Population  Thinness  1-19 years Thinness 5-9 years  \
# 228     9473172                   2.0                2.1
# ...

# %% [markdown]
# ##### INFERENCE:-
#     In the  3 extreme values in alcohol consumption 2 are from Estonia where Alcohol is 16.99 and 17.87.One Extreme Values from Belarus

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Create a column 'Life_expectancy_level' such that it will contain three levels (High, Medium, Low) based on the life expectancy </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Check how life expectancy has changed over the years in China</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data_china=data[data['Country']=='China']
data_china
# Out:
#     Country  Year      Status  Life expectancy  Adult mortality  \
# 560   China  2015  Developing             76.1             85.0
# 561   China  2014  Developing             75.8             86.0
# 562   China  2013  Developing             75.6             88.0
# 563   China  2012  Developing             75.4             89.0
# 564   China  2011  Developing             75.2             91.0
# 565   China  2010  Developing             75.0             92.0
# 566   China  2009  Developing             74.9             93.0
# 567   China  2008  Developing             74.5             97.0
# 568   China  2007  Developing             74.4             96.0
# 569   China  2006  Developing             74.2             98.0
# 570   China  2005  Developing             73.9             99.0
# 571   China  2004  Developing             73.5             11.0
# 572   China  2003  Developing             73.1             13.0
# 573   China  2002  Developing             72.7             16.0
# ...

# %%
data_china[['Country','Year','Status','Life expectancy']]
# Out:
#     Country  Year      Status  Life expectancy
# 560   China  2015  Developing             76.1
# 561   China  2014  Developing             75.8
# 562   China  2013  Developing             75.6
# 563   China  2012  Developing             75.4
# 564   China  2011  Developing             75.2
# 565   China  2010  Developing             75.0
# 566   China  2009  Developing             74.9
# 567   China  2008  Developing             74.5
# 568   China  2007  Developing             74.4
# 569   China  2006  Developing             74.2
# 570   China  2005  Developing             73.9
# 571   China  2004  Developing             73.5
# 572   China  2003  Developing             73.1
# 573   China  2002  Developing             72.7
# 574   China  2001  Developing             72.2
# 575   China  2000  Developing             71.7

# %%
# type your code here
sns.lineplot(data=data_china,x='Year',y='Life expectancy')
plt.show()

# %% [markdown]
# ##### INFERENCE:-
#     Life expectancy is almost Constantly increasing in China.Due to Improvement in Health Infrascture
